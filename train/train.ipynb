# %% [markdown]
# # 学習

# %%
from ultralytics import YOLO

# ベースとするモデル
model = YOLO('./models/yolov8n.pt')

# M1 macのGPUを使ってモデルを学習
results = model.train(
    data='./datasets/data.yaml',
    epochs=3,
    imgsz=640
)
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.10 torch-2.1.2 CPU
# yolo/engine/trainer: task=detect, mode=train, model=./models/yolov8n.pt, data=./datasets/data.yaml, epochs=3, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, min_memory=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, split=val, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/Users/yono/.pyenv/runs/detect/train
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.Detect                [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# COMET WARNING: Can not parse empty Comet API key
# WARNING ⚠️ Comet not initialized correctly, not logging this run. Comet.ml requires an API key. Please provide as the first argument to Experiment(api_key) or as an environment variable named COMET_API_KEY
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /Users/yono/datasets/labels/train.cache... 10 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10/10 [00:00<?, ?it/s]
# val: Scanning /Users/yono/datasets/labels/val.cache... 5 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Plotting labels to /Users/yono/.pyenv/runs/detect/train/labels.jpg...
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/plotting.py:201: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   plt.savefig(save_dir / 'labels.jpg', dpi=200)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/yono/.pyenv/runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3         0G      1.499      2.698      1.712         66        640: 100%|██████████| 1/1 [00:06<00:00,  6.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
#                    all          5         17     0.0113          1      0.182     0.0572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3         0G      1.429      2.685      1.666         35        640: 100%|██████████| 1/1 [00:07<00:00,  7.75s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
#                    all          5         17     0.0113          1       0.17     0.0594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3         0G      1.667      2.639      1.761         72        640: 100%|██████████| 1/1 [00:07<00:00,  7.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
#                    all          5         17     0.0113          1      0.164     0.0606
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
#
# 3 epochs completed in 0.009 hours.
# Optimizer stripped from /Users/yono/.pyenv/runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from /Users/yono/.pyenv/runs/detect/train/weights/best.pt, 6.2MB
#
# Validating /Users/yono/.pyenv/runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.10 torch-2.1.2 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:292: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:314: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
#                    all          5         17     0.0113          1      0.163     0.0605
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12520 (\N{KATAKANA LETTER YO}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# /Users/yono/.pyenv/versions/3.9.10/lib/python3.9/site-packages/ultralytics/yolo/utils/metrics.py:258: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.savefig(Path(save_dir) / 'confusion_matrix.png', dpi=250)
# Speed: 2.6ms preprocess, 127.0ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to /Users/yono/.pyenv/runs/detect/train
# Results saved to /Users/yono/.pyenv/runs/detect/train

# %%
from PIL import Image
from ultralytics import YOLO

model = YOLO('./models/last.pt')
res = model.predict("test.jpg",save=False, conf=0.1)
Image.fromarray(res[0].plot()[:, :, ::-1])
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.10 torch-2.1.2 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /Users/yono/Documents/work/Edge-AI-for-video-demo/train/test.jpg: 480x640 (no detections), 117.7ms
# Speed: 1.0ms preprocess, 117.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=600x450>
